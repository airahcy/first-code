# %% [markdown]
# # Pandas merge tutorial with cellphone usage data
# In this case, we will examines three datasets that are related.
# 1. examine the user_usage.csv, user_device.csv and android_devices.csv:
#     1. what is the shape of each data
#     2. what is use_id and user_id
#     3. which variable uniquely identify each row in each dataset
#     (can each user have multiple usages and multiple devices?)
# 2. how to get average usages for each type of devices
#     1. merge user_usage with user_device
#     2. compare the shape of the results with the shape of original datasets
#     3. left merge, right merge, inner merge and outer merge
#     4, identify origins of records in an outer merge
# 3. what if the merge key (primary key) is not unique?
# 4. exercise: get average usage for each phone brand

# %%
import pandas as pd
pd.set_option('max_rows', None)
pd.set_option('max_columns', None)

# %% [markdown]
# ### read and examine data

# %%
user_usage = pd.read_csv("user_usage.csv")
user_device = pd.read_csv("user_device.csv")
devices = pd.read_csv("android_devices.csv")

# %%
for data in [user_usage, user_device, devices]:
    print(' ')
    print(data.head())
    print('the data has {} rows'.format(data.shape[0]) )
    print('the number of unique values in each row:')
    print( data.nunique().reset_index()  )
# Out:
#
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
# the data has 240 rows
# the number of unique values in each row:
#                      index    0
# 0  outgoing_mins_per_month  178
# 1   outgoing_sms_per_month  169
# 2               monthly_mb   83
# 3                   use_id  240
#
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1
# the data has 272 rows
# the number of unique values in each row:
#               index    0
# 0            use_id  272
# 1           user_id  172
# 2          platform    2
# 3  platform_version   15
# 4            device   72
# 5       use_type_id    3
#
#   Retail Branding Marketing Name    Device                      Model
# 0             NaN            NaN    AD681H  Smartfren Andromax AD681H
# 1             NaN            NaN     FJL21                      FJL21
# 2             NaN            NaN       T31              Panasonic T31
# 3             NaN            NaN  hws7721g         MediaPad 7 Youth 2
# 4              3Q        OC1020A   OC1020A                    OC1020A
# the data has 14546 rows
# the number of unique values in each row:
#              index      0
# 0  Retail Branding    605
# 1   Marketing Name   8631
# 2           Device   9830
# 3            Model  12883

# %% [markdown]
# ### merge user_usage with user_device

# %%
merged = pd.merge(user_usage, user_device, on='use_id')
merged.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %%
merged.shape
# Out:
# (159, 9)

# %%
merged = pd.merge(user_usage, user_device, how = 'left', on='use_id')
merged.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0  12921.0  android               4.3  GT-I9505          1.0
# 1  28714.0  android               6.0  SM-G930F          1.0
# 2  28714.0  android               6.0  SM-G930F          1.0
# 3  29592.0  android               5.1     D2303          1.0
# 4  28217.0  android               5.1  SM-G361F          1.0

# %%
merged.shape
# Out:
# (240, 9)

# %%
merged = pd.merge(user_usage, user_device, how = 'right', on='use_id')
merged.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      NaN                     NaN         NaN   22782
# 1                      NaN                     NaN         NaN   22783
# 2                      NaN                     NaN         NaN   22784
# 3                      NaN                     NaN         NaN   22785
# 4                      NaN                     NaN         NaN   22786
#
#    user_id platform  platform_version     device  use_type_id
# 0    26980      ios              10.2  iPhone7,2            2
# 1    29628  android               6.0    Nexus 5            3
# 2    28473  android               5.1   SM-G903F            1
# 3    15200      ios              10.2  iPhone7,2            3
# 4    28239  android               6.0  ONE E1003            1

# %%
merged.shape
# Out:
# (272, 9)

# %% [markdown]
# ### duplicate merge key

# %%
user_usage2 = user_usage.copy()
user_device2 = user_device.copy()
user_usage2.loc[user_usage2['use_id']==22787, 'use_id']=22788
user_device2.loc[user_device2['use_id']==22787, 'use_id']=22788

# %%
merged = pd.merge(user_usage2, user_device2, on='use_id')
merged.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22788
# 1                    21.97                    4.82     1557.33   22788
# 2                  1710.08                  136.88     7267.55   22788
# 3                  1710.08                  136.88     7267.55   22788
# 4                  1710.08                  136.88     7267.55   22789
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    12921  android               4.3  GT-I9505            1
# 3    28714  android               6.0  SM-G930F            1
# 4    28714  android               6.0  SM-G930F            1

# %%
merged.shape
# Out:
# (161, 9)

# %%
merged[merged['use_id']==22788]
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22788
# 1                    21.97                    4.82     1557.33   22788
# 2                  1710.08                  136.88     7267.55   22788
# 3                  1710.08                  136.88     7267.55   22788
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    12921  android               4.3  GT-I9505            1
# 3    28714  android               6.0  SM-G930F            1

# %% [markdown]
# ### merge phone brand

# %%
merged1 = pd.merge(user_usage, user_device, how = 'left', on='use_id')
merged2 = pd.merge(merged1, devices[['Device', 'Retail Branding']], how = 'inner', left_on = 'device', right_on = 'Device')
merged2.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    94.46                   35.17      519.12   22790
# 1                    99.23                   35.58      519.12   22854
# 2                   283.30                  107.47    15573.33   22806
# 3                   283.30                  107.47    15573.33   22806
# 4                    57.49                   16.73    15573.33   22839
#
#    user_id platform  platform_version device  use_type_id Device  \
# 0  29592.0  android               5.1  D2303          1.0  D2303
# 1  29592.0  android               5.1  D2303          1.0  D2303
# 2  21615.0  android               6.0  A0001          1.0  A0001
# 3  21615.0  android               6.0  A0001          1.0  A0001
# 4  29655.0  android               6.0  A0001          1.0  A0001
#
#   Retail Branding
# 0            Sony
# 1            Sony
# 2         OnePlus
# 3         OnePlus
# 4         OnePlus
